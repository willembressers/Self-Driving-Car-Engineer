# %% [markdown]
# # Experimentation
#
# ## Changelog
# ### 1.0.0:
# - initial setup
#
# ### 1.0.1:
# - rescaling to 1/127
# - limit visualisations
#
# ### 1.0.2:
# - train with validation data
# - train on 50 epochs
# - add (early stopping & reduce on lr) callbacks
# - add visualisations
# - fix seed (for reproducalble results)
#
# ### 1.0.3:
# - Add dropout layer
# - add steps_per_epoch

# %%
# python core packages
import os
import sys
import pickle

# 3rd party packages
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# fix seed
np.random.seed(1234)
tf.random.set_seed(4567)

print(f'\n-> Python: {sys.version}')
print(f'-> Tensorflow: {tf.__version__}')
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2
#
# -> Python: 3.9.2 (v3.9.2:1a79785e3e, Feb 19 2021, 09:06:10)
# [Clang 6.0 (clang-600.0.57)]
# -> Tensorflow: 2.5.0-rc1

# %% [markdown]
# ## Define parameters

# %%
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 128
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## Load the data

# %%
with open(os.path.join(os.pardir, 'data', 'processed', 'traffic-signs-data', 'train.p'), mode='rb') as f:
    train = pickle.load(f)
    
with open(os.path.join(os.pardir, 'data', 'processed', 'traffic-signs-data', 'valid.p'), mode='rb') as f:
    valid = pickle.load(f)
    
with open(os.path.join(os.pardir, 'data', 'processed', 'traffic-signs-data', 'test.p'), mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# TODO: Number of training examples
n_train = X_train.shape[0]
print(f'-> Number of training examples = {n_train}')

# What's the shape of an traffic sign image?
image_shape = X_train.shape[1:3]
print(f'-> Image data shape = {image_shape}')

# How many unique classes/labels there are in the dataset.
n_classes = len(set(y_train))
print(f'-> Number of classes = {n_classes}')

# load the sign data
signnames = pd.read_csv(os.path.join(os.pardir, 'data', 'processed', 'signnames.csv')).set_index('ClassId')

# create a label_map
class_names = signnames.to_dict()['SignName']

# show some
signnames.head()
# Out:
# -> Number of training examples = 34799
# -> Image data shape = (32, 32)
# -> Number of classes = 43
#                      SignName
# ClassId
# 0        Speed limit (20km/h)
# 1        Speed limit (30km/h)
# 2        Speed limit (50km/h)
# 3        Speed limit (60km/h)
# 4        Speed limit (70km/h)

# %% [markdown]
# ## Preprocess the data

# %%
# =============================================================================
# load data
# =============================================================================

# create tensorflow datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)
valid_ds = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# =============================================================================
# prepare
# =============================================================================

def plot_dataset(dataset, n_columns = 6, n_rows = 3):
    plt.figure(figsize=(22, 10))
    for images, labels in dataset.take(1):
        for i in range(n_columns * n_rows):
            ax = plt.subplot(n_rows, n_columns, i + 1)
            plt.imshow(images[i].numpy(), cmap=plt.cm.binary)
            plt.title(f'{class_names[labels[i].numpy()]} ({labels[i].numpy()})')

def preprocess(image, label):
    # cast the input
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.int32)
    
    # process the image
    rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)
    image = rescale(image)
    
    # return 
    return image, label

def prepare(dataset):
    # Cast
    dataset = dataset.map(lambda x, y: preprocess(x, y), num_parallel_calls=AUTOTUNE)

    return dataset

# prepare the data(sets)
train_ds = prepare(train_ds)
valid_ds = prepare(valid_ds)
test_ds = prepare(test_ds)

# check if normalization works between [0,1]
image_batch, labels_batch = next(iter(train_ds))
print(f'-> Image normalization check; min={np.min(image_batch[0])}, max={np.max(image_batch[0])}')

# plot some training images
plot_dataset(train_ds)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -> Image normalization check; min=-0.8509804010391235, max=1.0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Model architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(n_classes)
])

# compile the model
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy']
)

# show a summary 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               393344
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 398,891
# Trainable params: 398,891
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
steps_per_epoch = n_train//BATCH_SIZE
print(f'-> steps per epoch = {steps_per_epoch}')

# callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=6),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5),
]

# train the model
history = model.fit(
    train_ds, 
    epochs=50,
    validation_data=valid_ds,
    callbacks=callbacks,
    steps_per_epoch=steps_per_epoch,
)
# Out:
# -> steps per epoch = 271
# Epoch 1/50
# 271/271 [==============================] - 3s 7ms/step - loss: 2.3998 - accuracy: 0.3785 - val_loss: 1.8400 - val_accuracy: 0.4676
# Epoch 2/50
# 271/271 [==============================] - 2s 6ms/step - loss: 1.3047 - accuracy: 0.6187 - val_loss: 1.3890 - val_accuracy: 0.5794
# Epoch 3/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.8825 - accuracy: 0.7292 - val_loss: 1.1420 - val_accuracy: 0.6374
# Epoch 4/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.7131 - accuracy: 0.7817 - val_loss: 1.1405 - val_accuracy: 0.6560
# Epoch 5/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.5637 - accuracy: 0.8283 - val_loss: 1.0003 - val_accuracy: 0.7138
# Epoch 6/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.5302 - accuracy: 0.8393 - val_loss: 0.9135 - val_accuracy: 0.7270
# Epoch 7/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.4627 - accuracy: 0.8583 - val_loss: 0.8529 - val_accuracy: 0.7741
# Epoch 8/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.4415 - accuracy: 0.8669 - val_loss: 0.8442 - val_accuracy: 0.7274
# Epoch 9/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.4070 - accuracy: 0.8753 - val_loss: 0.8955 - val_accuracy: 0.7410
# Epoch 10/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.3957 - accuracy: 0.8805 - val_loss: 0.7647 - val_accuracy: 0.8020
# Epoch 11/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.3989 - accuracy: 0.8793 - val_loss: 0.9992 - val_accuracy: 0.7302
# Epoch 12/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.3468 - accuracy: 0.8918 - val_loss: 0.9976 - val_accuracy: 0.7254
# Epoch 13/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.3635 - accuracy: 0.8890 - val_loss: 0.9261 - val_accuracy: 0.7646
# Epoch 14/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.3343 - accuracy: 0.8986 - val_loss: 0.8389 - val_accuracy: 0.7798
# Epoch 15/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.3150 - accuracy: 0.9033 - val_loss: 0.9377 - val_accuracy: 0.7580
# Epoch 16/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.2677 - accuracy: 0.9208 - val_loss: 0.7131 - val_accuracy: 0.8195
# Epoch 17/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.2090 - accuracy: 0.9409 - val_loss: 0.6524 - val_accuracy: 0.8383
# Epoch 18/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1937 - accuracy: 0.9461 - val_loss: 0.6119 - val_accuracy: 0.8519
# Epoch 19/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1851 - accuracy: 0.9477 - val_loss: 0.6348 - val_accuracy: 0.8438
# Epoch 20/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1846 - accuracy: 0.9466 - val_loss: 0.6147 - val_accuracy: 0.8463
# Epoch 21/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1675 - accuracy: 0.9528 - val_loss: 0.6433 - val_accuracy: 0.8381
# Epoch 22/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1655 - accuracy: 0.9532 - val_loss: 0.6248 - val_accuracy: 0.8526
# Epoch 23/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1680 - accuracy: 0.9549 - val_loss: 0.6162 - val_accuracy: 0.8474
# Epoch 24/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1753 - accuracy: 0.9528 - val_loss: 0.6112 - val_accuracy: 0.8494
# Epoch 25/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1655 - accuracy: 0.9547 - val_loss: 0.6079 - val_accuracy: 0.8512
# Epoch 26/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1608 - accuracy: 0.9575 - val_loss: 0.6117 - val_accuracy: 0.8481
# Epoch 27/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1614 - accuracy: 0.9585 - val_loss: 0.6132 - val_accuracy: 0.8469
# Epoch 28/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1630 - accuracy: 0.9564 - val_loss: 0.6019 - val_accuracy: 0.8526
# Epoch 29/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1560 - accuracy: 0.9573 - val_loss: 0.6156 - val_accuracy: 0.8420
# Epoch 30/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1606 - accuracy: 0.9588 - val_loss: 0.6063 - val_accuracy: 0.8501
# Epoch 31/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1597 - accuracy: 0.9578 - val_loss: 0.6008 - val_accuracy: 0.8574
# Epoch 32/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1542 - accuracy: 0.9603 - val_loss: 0.6078 - val_accuracy: 0.8492
# Epoch 33/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1562 - accuracy: 0.9581 - val_loss: 0.6064 - val_accuracy: 0.8531
# Epoch 34/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1531 - accuracy: 0.9590 - val_loss: 0.6103 - val_accuracy: 0.8481
# Epoch 35/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1546 - accuracy: 0.9598 - val_loss: 0.6084 - val_accuracy: 0.8517
# Epoch 36/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1534 - accuracy: 0.9591 - val_loss: 0.6063 - val_accuracy: 0.8522
# Epoch 37/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1741 - accuracy: 0.9549 - val_loss: 0.5731 - val_accuracy: 0.8687
# Epoch 38/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1624 - accuracy: 0.9576 - val_loss: 0.5695 - val_accuracy: 0.8689
# Epoch 39/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1576 - accuracy: 0.9600 - val_loss: 0.5686 - val_accuracy: 0.8707
# Epoch 40/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1555 - accuracy: 0.9613 - val_loss: 0.5681 - val_accuracy: 0.8705
# Epoch 41/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1579 - accuracy: 0.9596 - val_loss: 0.5667 - val_accuracy: 0.8707
# Epoch 42/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1602 - accuracy: 0.9573 - val_loss: 0.5665 - val_accuracy: 0.8703
# Epoch 43/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1626 - accuracy: 0.9580 - val_loss: 0.5668 - val_accuracy: 0.8696
# Epoch 44/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1606 - accuracy: 0.9594 - val_loss: 0.5665 - val_accuracy: 0.8703
# Epoch 45/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1544 - accuracy: 0.9607 - val_loss: 0.5672 - val_accuracy: 0.8705
# Epoch 46/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1593 - accuracy: 0.9609 - val_loss: 0.5669 - val_accuracy: 0.8703
# Epoch 47/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1540 - accuracy: 0.9605 - val_loss: 0.5664 - val_accuracy: 0.8701
# Epoch 48/50
# 271/271 [==============================] - 2s 7ms/step - loss: 0.1571 - accuracy: 0.9592 - val_loss: 0.5661 - val_accuracy: 0.8698
# Epoch 49/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1550 - accuracy: 0.9587 - val_loss: 0.5660 - val_accuracy: 0.8696
# Epoch 50/50
# 271/271 [==============================] - 2s 6ms/step - loss: 0.1513 - accuracy: 0.9612 - val_loss: 0.5659 - val_accuracy: 0.8694

# %%
plt.figure(figsize=(22, 10))

# summarize history for accuracy
plt.subplot(3, 1, 1)
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([0,1.0])
plt.title('Training & Validation Accuracy')

# summarize history for loss
plt.subplot(3, 1, 2)
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([0,1.0])
plt.title('Training & Validation Loss')
plt.xlabel('epoch')

# summarize history for learning rate
plt.subplot(3, 1, 3)
plt.plot(history.history['lr'])
plt.title('Learning rate')
plt.ylabel('value')
plt.xlabel('epoch')

plt.show()

# %% [markdown]
# ## Evaluate the model

# %%
bechmarks = []

loss, acc = model.evaluate(train_ds, steps=steps_per_epoch, verbose=0)
bechmarks.append({'dataset':'training', 'accuracy':acc, 'loss':loss})

loss, acc = model.evaluate(valid_ds, verbose=0)
bechmarks.append({'dataset':'validation', 'accuracy':acc, 'loss':loss})

loss, acc = model.evaluate(test_ds, verbose=0)
bechmarks.append({'dataset':'testing', 'accuracy':acc, 'loss':loss})

# plot the accuracy per dataset
pd.DataFrame(bechmarks)\
    .set_index('dataset')\
    .sort_values('accuracy', ascending=True)['accuracy']\
    .plot(kind='barh', figsize=(20, 5), title='ACCURACY per dataset')\
    .set(xlabel="Accuracy", ylabel="dataset", xlim=[0,1.0])
# Out:
# [Text(0.5, 0, 'Accuracy'), Text(0, 0.5, 'dataset'), (0.0, 1.0)]
